# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import seaborn as sns
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../data/cherry_blossoms.csv', sep=';')
df.head()
# Out:
#    year  doy  temp  temp_upper  temp_lower
# 0   801  NaN   NaN         NaN         NaN
# 1   802  NaN   NaN         NaN         NaN
# 2   803  NaN   NaN         NaN         NaN
# 3   804  NaN   NaN         NaN         NaN
# 4   805  NaN   NaN         NaN         NaN

# %%
sns.lineplot(data=df, x='year', y='temp')
# Out:
# <Axes: xlabel='year', ylabel='temp'>

# %%
sns.lineplot(data=df, x='year', y='doy')
# Out:
# <Axes: xlabel='year', ylabel='doy'>

# %%
df_long = df.melt(id_vars=["year"], value_vars=["temp", "temp_upper", "temp_lower"], var_name="temp_type", value_name="value")
sns.lineplot(data=df_long, x='year', y='value', hue='temp_type')
# Out:
# <Axes: xlabel='year', ylabel='value'>
